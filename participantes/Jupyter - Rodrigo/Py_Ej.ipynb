# %% [markdown]
# # Tablas en Python

# %% [markdown]
# Este es un ejemplo de cómo usar una tabla en Python:

# %%
import pandas as pd

tabla = pd.DataFrame(data = [[1,1],[2,4],[3,9]],
                     columns = ['numero','cuadrado'])

tabla
# Out:
#    numero  cuadrado
# 0       1         1
# 1       2         4
# 2       3         9

# %% [markdown]
# # Gráficos en Python

# %% [markdown]
# Este es un ejemplo de cómo emplear un gráfico en Python:

# %%
import matplotlib.pyplot as plt 

x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)
plt.show()
